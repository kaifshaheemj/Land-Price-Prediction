# %% [markdown]
# <a href="https://colab.research.google.com/github/kaifshaheemj/Land-Price-Prediction/blob/main/Land%20Price%20Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from  google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-27df4ee6-c1ba-4cf0-a0d4-9fd65c9ee1e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27df4ee6-c1ba-4cf0-a0d4-9fd65c9ee1e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_excel('land_price prediction.xlsx')
data
# Out:
#     land      price
# 0   1000     2245.0
# 1   2000     4575.0
# 2   3000     6874.0
# 3   4000     8878.0
# 4   5000        NaN
# 5   6000    12457.0
# 6   7000    14758.0
# 7   8000    16785.0
# 8  10000  2078900.0

# %%
datawithNaN = data
data
# Out:
#     land      price
# 0   1000     2245.0
# 1   2000     4575.0
# 2   3000     6874.0
# 3   4000     8878.0
# 4   5000        NaN
# 5   6000    12457.0
# 6   7000    14758.0
# 7   8000    16785.0
# 8  10000  2078900.0

# %%
print(data.shape)
# Out:
# (9, 2)

# %%
data.describe()
# Out:
#                land         price
# count      9.000000  8.000000e+00
# mean    5111.111111  2.681840e+05
# std     2934.469477  7.316567e+05
# min     1000.000000  2.245000e+03
# 25%     3000.000000  6.299250e+03
# 50%     5000.000000  1.066750e+04
# 75%     7000.000000  1.526475e+04
# max    10000.000000  2.078900e+06

# %%
data.isna().any()
# Out:
# land     False
# price     True
# dtype: bool

# %% [markdown]
# data.price.mean()

# %%
mean = data.price.fillna(data.price.mean())
mean
# Out:
# 0       2245.0
# 1       4575.0
# 2       6874.0
# 3       8878.0
# 4     268184.0
# 5      12457.0
# 6      14758.0
# 7      16785.0
# 8    2078900.0
# Name: price, dtype: float64

# %%
median = data.price.fillna(data.price.median())
median
# Out:
# 0       2245.0
# 1       4575.0
# 2       6874.0
# 3       8878.0
# 4      10667.5
# 5      12457.0
# 6      14758.0
# 7      16785.0
# 8    2078900.0
# Name: price, dtype: float64

# %%
data.describe()
# Out:
#                land         price
# count      9.000000  8.000000e+00
# mean    5111.111111  2.681840e+05
# std     2934.469477  7.316567e+05
# min     1000.000000  2.245000e+03
# 25%     3000.000000  6.299250e+03
# 50%     5000.000000  1.066750e+04
# 75%     7000.000000  1.526475e+04
# max    10000.000000  2.078900e+06

# %%
percentile = data.price.quantile(0.75)
percentile
# Out:
# 15264.75

# %%
outlier = data[data.price < percentile]
outlier
# Out:
#    land    price
# 0  1000   2245.0
# 1  2000   4575.0
# 2  3000   6874.0
# 3  4000   8878.0
# 5  6000  12457.0
# 6  7000  14758.0
